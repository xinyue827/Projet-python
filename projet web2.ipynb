# %%
import time
import random
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import re

# %%
cService = webdriver.ChromeService(executable_path=r'C:\Users\10144\.wdm\chromedriver-win64\chromedriver.exe')
driver = webdriver.Chrome(service = cService)
url ="https://www.hellowork.com/fr-fr/emploi/recherche.html?k=data&l=%C3%8Ele-de-France&l_autocomplete=http%3A%2F%2Fwww.rj.com%2Fcommun%2Flocalite%2Fregion%2F11&c=Alternance&p=1#47572052"
driver.get(url)

# %%
links=[]
for p in range(1,27):
    url = f"{'https://www.hellowork.com/fr-fr/emploi/recherche.html?k=data&l=%C3%8Ele-de-France&l_autocomplete=http%3A%2F%2Fwww.rj.com%2Fcommun%2Flocalite%2Fregion%2F11&c=Alternance'}&p={p}"
    driver.get(url)
    time.sleep(3)
    my_range = [i for i in range(1, 31)]
    for i in my_range:
        xpath_expression = '/html/body/main/section/div/section/ul[1]/li[{}]/div/div[2]/div[1]/span[2]/h3/a'.format(i)
        elements=driver.find_elements(By.XPATH, xpath_expression)
        if not elements: 
            continue
        link=elements[0].get_attribute('href')
        links.append(link)

# %%
len(links)
# Out:
# 752

# %%
emails_found = []

for link in links:
    driver.get(link)
    content = driver.page_source 
    soup = BeautifulSoup(content, 'html.parser')
    job_description_element = soup.find('div', class_='tw-col-span-full lg:tw-col-span-8')
        
    email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
    emails = re.findall(email_pattern, job_description)

    if emails:
        for email in emails:
            emails_found.append(email)
            
print(emails_found)
# Out:
# []

# %%
links=[]
my_range = [i for i in range(1, 31)]
for i in my_range:
    xpath_expression = '/html/body/main/section/div/section/ul[1]/li[{}]/div/div[2]/div[1]/span[2]/h3/a'.format(i)
    elements=driver.find_elements(By.XPATH, xpath_expression)
    if not elements: 
        continue
    link=elements[0].get_attribute('href')
    links.append(link)

# %%
for link in links:
    driver.get(link)
    content = driver.page_source 
    soup = BeautifulSoup(content, 'html.parser')
    job_description= soup.find('div', class_='tw-col-span-full lg:tw-col-span-8')
    job = job_description.get_text()
    print(job)
# Out:
# Alternance Data Management H/F
# Eramet
#
#
# Paris 15e - 75
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Les missions du poste
#
#
#                 Les données sont générées à chaque étape de la chaîne de valeur du Groupe Eramet (Exploration, Extraction, Transformation, Transport). La remontée des données est cruciale pour l'amélioration des opérations et l'atteinte des ambitions environnementales du Groupe ; elle constitue un véritable défi dans un contexte industriel complexe, multi-activités, international et multiculturel.L'équipe de Transformation & Intégration des Opérations, au sein de la Direction Technique Groupe, est en charge de la collecte, la standardisation et la mise à disposition des données pour le pilotage en temps réel des Opérations. L'alternant interviendra auprès de la Responsable Data Management Group en support à l'ensemble des actions de gouvernance et gestion des données sur toutes les filiales du Groupe (Gabon, Norvège, Sénégal, Argentine, Indonésie, Nouvelle-Calédonie).Dans ce contexte, l'équipe Transformation & IROC, recherche un/une Alternant(e) ou Stagiaire Data Management H/F.L'objectif du stage est d'accompagner Eramet dans sa transformation digitale en participant au déploiement de la démarche de Data Gouvernance et aux activités qui en découlent (Data Mapping, Data Cataloging, Data Management, Data Quality, Formation/Acculturation...) sur l'ensemble de la chaine de valeur des opérations.Pour ce faire, il est proposé de se baser notamment sur la technique du paramétrage technique des réserves proposée par G. Mathéron dans les années 70. Les tests et la mise en oeuvre pratique se feront sur une sélection réduite de gisements (preuve de concept).Rejoignez Eramet, groupe minier responsable et engagé pour une aventure professionnelle passionnante et riche en opportunités. Révélez tout votre potentiel avec notre offre d'alternance ou stage !Missions :Data Gouvernance :Identifier les données clés de l'entreprises, leurs interactions (positionnement dans la chaîne de valeur), leurs usages, les indicateurs et métadonnées associées (définitions, règles métiers, règles de calculs, unités...) et les rôles clésEvaluer et améliorer la maturité data gouvernance sur l'ensemble des processusIdentifier les personnes clés et les organisations à mettre en place pour favoriser l'essor de la donnéeFormaliser les échanges de données afin de garantir la traçabilité des données en cas d'auditS'assurer de la documentation de la donnée dans le catalogue d'entrepriseAccompagner les équipes opérationnelles dans la mise en place et le déploiement de standards de gestion des données liés à leurs différentes activités (définitions des concepts métiers avec leurs métadonnées descriptives, des indicateurs de suivis, des référentiels, règles de qualités de données, outils centralisés...)Former/acculturer les métiers pour garantir l'adoption des processus de mises en gouvernance des donnéesData Management/ Data Analyse :Définir les règles d'accès à la donnée et travailler en relation avec la DSI afin de créer/faire évoluer les modèles de données et les outils de saisi et de mise à disposition des donnéesIdentifier les douleurs métier et les points durs et proposer des solutions de remédiations en accord avec les différentes parties prenantes (opérations, CTO, DSI)Accompagner les métiers dans l'identification des données clés de pilotage et à les valoriser dans des tableaux de bords ou tout autre outil de d'analyse de performance ou de suivi environnemental : maquettage, rédaction de cahier des charges, déploiement de solutionsTransverses :S'assurer de partager son travail de façon transverse afin de mettre en visibilité et de s'inscrire dans les initiatives en cours métiers, CTO, DSI (ex : Intégrer le processus de remontée des données au coeur de process purement métier)Participer à l'animation de la feuille de route et à la médiation transverse entre toutes les parties prenantes afin d'aider à la priorisation des chantiers.Le poste est basé au siège du groupe Eramet à Paris dans le 15ème arrondissement et sera pourvu pour une durée de six (06) mois à compt ...
#
#
#
#
#                 Le profil recherché
#
#
#                 -   Bac +4/5 en Géosciences, Génie minier, SIG - issu(e) d'une Formation dans la Gestion des données avec une appétence pour le domaine minier ou formation en Sciences de la terre avec une spécialisation dans la gestion des données-   Connaissances en SQL, bases de données relationnelles-   Connaissances d'outils permettant de capter les données, les transformer et de les valoriser (ETL, reporting)-   Capacité à réaliser des cartographies de remonté de données, identifier des points dures et des processus de remédiations (people, process, outil) pour garantir la qualité/intégrité des données-   Mettre en place des tableaux de bords de suivi de qualité des données-   Bonne maîtrise des outils du Pack Office-   Maîtrise du Français et de l'anglais (courant)-   Être curieux et ouvert d'esprit, force de proposition-   Être patient, pédagogue, avoir la capacité d'adaptation dans un contexte multiculturel-   Être à l'écoute et avoir un bon esprit d'analyse et de synthèse-   Être rigoureux et tenace-   Capable de communiquer avec aisance tant à l'oral qu'à l'écrit-   Savoir travailler en autonomie et en équipe-   Faire preuve de discrétion vis-à-vis des données et des activités de l'entreprise
#
#
#
#
#                 Infos complémentaires
#
#
#                 Chez Eramet, nous prenons soin de nos collaborateurs avec :une indemnité attrayante, des remboursements pour les activités sportives et culturelles et un accès à des plateformes Learning pour développer vos compétences.Une couverture santé et prévoyance premiumUn restaurant d'entreprise avec un rapport qualité-prix imbattable.Prise en charge à 100% de votre NavigoUn environnement international avec des projets exceptionnels et des opportunités de développement dans un groupe en expansionUn véritable Onboarding pour un démarrage réussi dans l'entrepriseSi vous êtes à la recherche d'un environnement de travail dynamique, inclusif et international, rejoignez-nous dès maintenant pour une expérience passionnante !Présent sur les cinq continents et regroupant plus de 70 nationalités, Eramet est par nature un groupe empreint de diversité. Convaincus que la diversité est un atout, nous nous engageons à accueillir tous les talents, quels que soient leur genre, leur handicap, leur âge, leur origine sociale ou culturelle, leur orientation sexuelle.
#
#
#
#
# Bienvenue chez Eramet
#
#
#                 Eramet est l'un des leaders mondiaux de l'industrie minière et métallurgique. En rejoignant un acteur clé de l'extraction de métaux, à forte valeur ajoutée, vous prenez le risque de ressentir d'intenses émotions dans chacune de vos missions !Avec 10400 collaborateurs présents dans 15 pays qui accompagnent la transition énergétique, Eramet est en quête perpétuelle de ressources précieuses. Et chez nous, la ressource précieuse, c'est vous !Rejoignez Eramet, laissez votre talent battre plus fort.
#
#
#
#
#
#
#
#
# Développeur Data H/F
# EDF
#
#
# Saint-Denis - 93
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#             « Parce que votre bien-être au travail fait partie de nos priorités. »
#
#
#
#                 Les missions du poste
#
#
#                 Vous avez envie de rejoindre un groupe performant et responsable ? Mettez votre talent au service d'EDF, champion de la croissance bas carbone.Vous travaillerez au sein du site EDF de CAP Ampère à Saint Denis.Vos missions :Dans le cadre de votre apprentissage, vous contribuerez à la gestion du Portefeuille de projet de la Cellule Transformation Numérique (environ 30 projets) en apportant des solutions de reporting et de suivi des affaires, en industrialisant de multiple outils de bases de données :-  Concevoir et mettre en oeuvre des modèles de données sémantique pour intégrer l'ensemble des données de l'ingénierie ;-  Préparer des données via des ETL ou des Logiques PowerQuery pour alimenter le Data HUB en conformité avec les modèles de données définis ;-  Contribuer activement à la construction de bases de données en particulier orienté graphe ;-  Développer les outils de Business Intelligence au service des métiers (WEB, R, Python) ;-  Automatiser les gestes Métier via Power Automate ou autres outils ;-  Assister à la gestion du portefeuille projet via les listes SharePoint et l'environnement office 365 ;-  Réaliser la documentation des fonctionnalités des outils développées (Description Technique, Protocole d'installation, Vidéo de démonstration...).Votre équipeAu sein d'EDF CI2T, vous intégrerez le  Pôle Numérique - SI - Cyber Sécurité composé de 15 personnes au sein du Département Technique Transverse.
#
#
#
#
#                 Le profil recherché
#
#
#                 A la rentrée 2024, vous préparerez un diplôme d'ingénieur ou un master d'une durée de 2 à 3 ans, dans le cadre d'un contrat d'apprentissage.Vous possédez une expérience dans le domaine de Data Préparation, de la conception d'outils de valorisation (PowerBI, Python...).Vous êtes curieux et avez envie de découvrir les nouvelles technologies ainsi que l'implication de la transformation numérique sur et en lien avec des métiers diverses.Vous savez allier esprit d'équipe et autonomie dans vos missions.Vous êtes à l'aise en reportant à l'écrit.Dans le groupe EDF, accueillir des personnes en situation de handicap fait partie de notre ADN.Notre objectif est d'ouvrir nos portes à toutes les compétences, toutes les énergies et toutes les personnalités sans exclusion. Le poste proposé est donc ouvert à toutes et à tous.
#
#
#
#
# Bienvenue chez EDF
#
#
#                 CI2T est l'unité d'ingénierie au service de la performance des parcs de production d'EDF.Elle rassemble les métiers de l'ingénierie thermique bas carbone et ceux du système/transport électrique. Ses 550 salariés, hommes et femmes, oeuvrent pour offrir de nouvelles solutions destinées à compenser l'intermittence du mix-énergétique et continuer à satisfaire ses 80 clients et partenaires en France et dans plus de 30 pays.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 7 de plus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0 / 12
# Alternance - Data - Charenton H/F
# BPCE IT
#
#
# Charenton-le-Pont - 94
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Les missions du poste
#
#
#                 Poste et missionsAu sein de la direction DPM (Direction Production Métier), la direction D4O met en oeuvre des solutions et une démarche innovante de gouvernance de la donnée autour d'une solution de log Management (log applicative et technique) THEIA à destination des productions applicatives et éditeurNotre stack est basé sur une architecture ELK permettant aujourd'hui l'ingestion de plus de 10 milliards d'événements quotidien avec une capacité de stockage de plusieurs centaines de térabyte de données.Notre expertise se déploie dans la définition, l'implémentation et l'administration des composants de cette solution par l'utilisation d'outils DEVOPS. Nous gérons pour cela des déploiements micro-segmentés permettant la mise en oeuvre de l'observabilité grâce à plusieurs puits de données contenant les logs et les indicateurs des applications du groupe BPCE.Ces solutions permettent d'implémenter l'utilisation de l'intelligence artificielle pour les opérations informatique, ou autrement dit l'AIops, au sein du groupe.Au sein du service DPM\_D4O\_DSO (Data Solution), votre mission consistera à apporter toute l'expertise nécessaire à l'exploitation de la plateforme ainsi que l'évolution de l'offre de service autour du bigdata et de l'intelligence artificielle :-  Assurer le bon fonctionnement de la solution AIops du groupe BPCE-  Développer et la promouvoir l'offre de service autours des solutions d'observabilité et de machine learning au bénéfice des productions applicatives et des métiers-  Accompagner nos équipes dans l'exploitation des résultats et de l'appropriation de la solution-  Développement de solution As a Service dans la politique de D4O utilisant les solutions DEVOPS du groupe-  La mise en oeuvre de nouveaux usages au service de nos équipes de production applicatives et éditeurs-  Rendre compte des avancements projets via des points hebdomadaire avec son tuteurProfil et compétences requisesSi ce défi t'attire, voici ce que l'on attend de toi :Ces premières compétences sont importantes :-  - Connaissance et appétence sur la data et la production informatique-  Des compétences sur les bases de données NoSql, idéalement elasticsearch-  Maîtrise des concepts de data gouvernance et de l'AIops (machine learning, generative AI)-  Maîtrise de linux, des outils DEVOPS et de python-  La connaissance des solutions de conteneurisationEt si en plus tu coches les cases suivantes, t'es le/la candidat.e idéal.e :-  Bon.ne communicant.e, tu fais preuve d'un sens de l'écoute et de diplomatie-  Dynamique, tu n'hésites à porter des sujets et faire des propositions : nous t'écouterons et t'aiderons !-  Implication, rigueur et fiabilité sont indispensables pour évoluer dans l'environnement exigeant IT d'un grand groupe bancaire : si tu fais preuve de ces qualités, tu as un rôle à jouer chez nous, maintenant et plus tard !-  Résilient et pugnace, tu fais preuve de persévérance dans la recherche d'informations et de solutions-  Polyvalent.e et organisé.e, tu as un bon esprit de synthèse et un sens critique qui te permettent de travailler au quotidien avec des interlocuteurs multiples.-  Rigouruex.se et pédagogue, tu as le sens du détail et de la réactivitéInformations complémentaires sur le posteEt si on parlait de votre rémunération et de vos avantages ?-  L'appel de l'international : Vous avez la possibilité d'être en relation notre partenaire à Porto !-  Ride like the Wind : Nous remboursons votre abonnement de transport à hauteur de 80%-  Emote & remote : Nous avons mis en place une politique télétravail pour tous nos collaborateurs, en offrant de 2 à 3 jours de télétravail par semaine.-  IT's a match : Nous embauchons très régulièrement nos alternants en CDI !
#
#
#
#
# Bienvenue chez BPCE IT
#
#
#                 Description de l'entrepriseTu veux participer à des projets informatiques challengeants, au coeur des nouvelles technologies, au sein du 2ème groupe bancaire français ? Embarque avec nous !BPCE Infogérance et Technologies, c'est 1 650 collaborateurs passionnés et engagés, répartis sur nos 14 sites en France.Notre ambition ? Proposer des services d'infrastructures, de sécurité informatique et de production applicative pour les utilisateurs du Groupe BPCE (Banques Populaires, Caisses d'Epargne, NATIXIS, Crédit coopératif...).BPCE-IT, construire ensemble la technologie la plus performante, innovante, utile et sûrePourquoi embarquer avec nous !-  IT specialist : Nous sommes une entité dont le coeur de métier est l'informatique.-  Wherever : BPCE IT, c'est 14 sites en France et du télétravail-  New horizons : Notre politique de mobilité interne et de montée en compétences vous ouvre le champ des possibles.-  More than a place to BE, a place to stay : vous bénéficierez d'un package de rémunération et d'avantages attractifs.-  Do IT ! : Nous sommes un financeur historique du sport en France et partenaire premium des Jeux Olympiques 2024.-  All-inclusive : Notre entreprise est engagée en faveur de la diversité et de l'inclusion. Nous accueillons tous les talents !
#
#
#
#
#
#
#
#
# Alternance - Appui Data H/F
# EDF
#
#
# Saint-Denis - 93
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#             « Parce que votre bien-être au travail fait partie de nos priorités. »
#
#
#
#                 Les missions du poste
#
#
#                 Cette année, faites partie des 6500 alternants à rejoindre le groupe EDF !Un Groupe international, champion de la croissance bas carbone qui lutte au quotidien contre le réchauffement climatique !Une entreprise engagée depuis plus de 30 ans aux côtés du sport français. Partenaire de Paris 2024, notre ambition est d'organiser les Jeux Olympiques et Paralympiques les plus responsables de l'Histoire.90% des étudiants recommandent EDF à l'issue de leur alternance ou de leur stage (source : enquête Happy Trainees 2023).Dans ce contexte, la Direction Division Production Nucléaire (DPN) propose, pour son Service MME SI (groupe Transverse), un contrat en alternance de 24 mois sur le poste d'Appui Data F/H.Vos missionsAu sein de l'équipe du projet DATA et sous la responsabilité du Chef de Projet BI, vous participerez aux principales missions suivantes :Appui des chefs de projet DATA.Contribuer à divers projets avec l'équipe locale de développement sur les outils de reporting / visualisation (BI / Tableau / Power BI).Participer aux plans de recettes de rapport / tableau de bord à la suite de montées de versions techniques ou fonctionnelles.Cette liste pourra évoluer en fonction des priorités de votre équipe, de vos attentes, vos envies, vos idées.
#
#
#
#
#                 Le profil recherché
#
#
#                 Votre profilA la rentrée 2024, vous serez titulaire d'un Bac +3, et vous souhaitez préparer un Master, spécialité informatique sur 2 ans, dans le cadre d'un contrat d'apprentissage.Compétences et qualités recherchéesAutonomieRigueurOrganisationCe qu'EDF peut vous offrirAvantagesVous déménagez pour votre alternance ? EDF peut vous aider à financer une partie de votre loyer.Vous profitez des activités sociales de l'entreprise.Vous bénéficiez d'une prime d'intéressement et d'une couverture sociale.Vous serez remboursé de 50% de votre titre de transportMerci de joindre à votre candidature : votre CV, une lettre de motivation.Besoin d'en savoir plus ? Nos alternants témoignent :En podcastEn vidéoDans le groupe EDF accueillir des personnes en situation de handicap fait partie de notre ADN. Notre objectif est d'ouvrir nos portes à toutes les compétences, toutes les énergies et toutes les personnalités sans exclusion. Le poste proposé est donc ouvert à toutes et à tous.
#
#
#
#
# Bienvenue chez EDF
#
#
#                 Vous souhaitez contribuer à un avenir énergétique responsable et bas carbone ? Vous recherchez des missions challengeantes dans une ambiance de travail agréable ?  Rejoignez plus de 171 000 collaboratrices et collaborateurs dans les nombreux métiers du groupe EDF.Avec ses entités d'ingénierie et 56 réacteurs en exploitation, la Division Production Nucléaire (DPN) d'EDF, présente sur tout le territoire, est le principal fournisseur d'électricité bas carbone en France. Le Parc nucléaire s'appuie sur le savoir-faire de personnels formés, compétents et engagés pour répondre au quotidien, en toute sûreté, à ses exigences de disponibilité, de performance et de respect de l'environnement. L'état-major de la DPN est implanté à Saint-Denis.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 7 de plus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0 / 12
# Alternance Assistant Chef de Projet Data H/F
# Altice Media - BFM RMC
#
#
# Paris 1er - 75
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Les missions du poste
#
#
#                 Intitulé du posteAlternance Assistant(e) Chef de projet DataDescription de la missionRattaché (e) au Data Product Owner, votre mission consistera à suivre et accompagner les projets en lien avec la Data monétisation au sein de la régie Altice Ads & Connect. Vous participerez à des challenges importants.-  Maintien, gestion de la base de données BtoB-  Collecte, analyse et segmentation des données digitales-  Création, maintien des segments IPTV/TVS et analyse des forecast-  Automatisation des catalogues de données sur Tableau Software-  Création des rapports de suivi de monétisation de la donnée sur Tableau Software-  Manipulation quotidienne des outils où transite la Data (DMP, Adservers, Tableau...)-  Support au commerce sur les réponses de Brief avec DATA (VOL/Display/TVS)-  Acculturation de l'ensemble la régie à la monétisation de la donnéeProfilBac +4/5 Master spécialisation Digital & Data.Qualifications :-  Maîtrise du Pack Office-  Maîtrise du langage SQL-  Connaissances des API-  Connaissance des outils BI (Tableau Software/Amazon Quicksite)-  Excellentes compétences de communication à l'oral comme à l'écrit.-  Vous avez un bon niveau d'anglais (oral et écrit)Qualités et Aptitudes particulières :Réactivité, autonomie et rigueur avec une forte capacité d'adaptation.Bon communiquant, aimant travailler en équipe. Vous êtes sensible au métier de la publicité et de ses enjeux.Profil capable de gérer des missions "hybrides" dans un environnement technique et businessContrat en Alternance :poste à pourvoir à partir du 26/08/2024Rythme souhaité : 4jours en entreprise/ 1 jours en coursAvantages :-  Remboursement de 75% des titres de transports-  Carte tickets restaurants-  RIE-  CSE-  Prime participation et intéressement-  Mutuelle d'entreprisePour postuler : CV+ LM à envoyer à Katia Apolinario ****@****.**
#
#
#
#
# Bienvenue chez Altice Media - BFM RMC
#
#
#                 Informations généralesRégie publicitaire du groupe Altice France, ALTICE MEDIA ADS& CONNECT commercialise les espaces publicitaires des marques BFMTV, BFMBusiness, BFM Paris, BFM Lyon, BFM Grand Lille, BFM Grand Littoral, BFM DICI,i24 News, RMC, RMC Découverte, RMC Story, RMC Sport et 01net.com.
#
#
#
#
#
#
#
#
# Alternance - Commercial Btob Data H/F
# Euridis Business School Paris
#
#
# Paris - 75
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Les missions du poste
#
#
#                 -  Vous aimez les challenges et accompagner vos clients ?-  Vous souhaitez monter en compétences et découvrir l'univers de la Data ?-  Vous appréciez travailler dans une équipe dynamique et à taille humaine ?Notre entreprise partenaire, société spécialisée dans la Data, recherche un Commercial BtoB en alternance pour rejoindre son équipe commerciale et accélérer son développement. Rejoignez une entreprise où performance rime avec bonne humeur et bien-être des collaborateurs.Cette offre est à pourvoir en partenariat avec l'école Euridis Business School. Pour accéder à cette alternance, le prétendant au poste intégrera le Mastère Ingénieur d'Affaires & Business Developer (rentrée septembre 2024).VOS MISSIONS :-  Prospecter et développer le portefeuille client au niveau national-  Analyser les besoins client et construire une offre y répondant-  Négocier les conditions commerciales-  Fidéliser le client et être garant de sa satisfaction
#
#
#
#
#                 Le profil recherché
#
#
#                 Vous serez titulaire d'un Bac +3 cette année et souhaitez intégrer le Mastère Ingénieur d'Affaires & Business Developer chez Euridis Business School. (rentrée septembre 2024).PROFIL-   Capacité d'écoute et d'analyse-   Goût du challenge et bonne organisation-   Idéalement, une première expérience (stage ou alternance) en commerceRejoignez-notre équipe !
#
#
#
#
# Bienvenue chez Euridis Business School Paris
#
#
#                 Euridis Business School est une école de commerce, leader en France sur des formations en vente BtoB, commerce international et digital business du Bac au Bac +5.-  8 campus sur toute la France-  50 500 € : le salaire moyen à la sortie du Mastère-  3ème meilleur Mastère en Business Developpement-  4ème meilleur Bachelor en Commerce, Vente & Négociation-  95 % des étudiants trouvent une entreprise dans les secteurs de l'industrie, des hautes technologies, de l'IT et du digital grâce à notre accompagnement.-  Réseau de 1500 entreprises partenaires#Expert Digital Business.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3 de plus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0 / 8
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# HelloWork a estimé le salaire pour cette offre d'alternance
# Le recruteur n'a pas communiqué le salaire de cette offre mais HelloWork vous propose une estimation (le salaire en alternance varie en fonction de l'âge et du niveau d'études du candidat).
#
#
# Estimation basse
# 477,07 €
#
#
#
# Estimation haute
# 1 766,92 €
#
#
#
#
# Cette information vous semble-t-elle utile ?
#
#
#                     Oui
#
#
#                     Non
#
#
#
# Merci pour votre retour !
#
#
#
#
#
#
# Apprenti.e Développeur Data & Bi H/F
# Safran
#
#
# Les Ulis - 91
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Les missions du poste
#
#
#                 La division Espace de Safran recherche un-e alternant-e passionné-e par les métiers de la data pour rejoindre notre équipe. Dans le cadre de cette alternance, vous aurez l'opportunité de contribuer à la montée en charge de notre équipe et à la mise en place des nouvelles infrastructures Analytics. Votre rôle consistera à mettre en place les flux de données et les rapports Power BI afin d'aider les métiers dans leurs tâches quotidiennes et leurs prises de décision.Mission :Vos missions principales seront les suivantes :1.	Mise en place des extractions de Données :- Utiliser Qlik Replicate pour extraire et traiter les données en conformité avec les besoins de nos métiers- Assurer la qualité et la fiabilité des flux de données, en veillant à leur intégrité et à leur cohérence.2.	Traitement et Stockage des Données :- Utiliser Snowflake comme plateforme de traitement et de stockage des données.- Concevoir et mettre en oeuvre des schémas de données efficaces pour répondre aux besoins analytiques de l'entreprise.- Optimiser les performances des requêtes SQL pour garantir des temps de réponse rapides.3.	Développement de Rapports Power BI :- Créer des rapports interactifs et intuitifs dans Power BI pour visualiser et analyser les données.- Collaborer avec les équipes métier pour comprendre leurs besoins et concevoir des tableaux de bord personnalisés.- Assurer la diffusion et la mise à jour régulière des rapports pour permettre une prise de décision éclairée.4.	Support aux Métiers :- Fournir un support technique et fonctionnel aux utilisateurs finaux de Power BI.- Répondre aux demandes de modification ou d'ajout de fonctionnalités dans les rapports existants.- Former les utilisateurs sur les bonnes pratiques d'utilisation des outils d'analyse de données.Environnement Technique :Dans le cadre de cette alternance, vous aurez l'opportunité de travailler avec les technologies suivantes :- Qlik Replicate pour l'extraction des données.- Snowflake pour le traitement et le stockage des données.- Power BI pour la restitution et la visualisation des données.
#
#
#
#
#                 Le profil recherché
#
#
#                 Nous recherchons un-e candidat-e dynamique et motivé-e, passionné-e par les métiers de la data et désireux-se d'apprendre et de se développer dans un environnement stimulant. Les qualifications et compétences suivantes seront nécessaires pour ce poste :-  Formation en informatique, data science, ou domaine connexe.-  Bonnes connaissances en bases de données relationnelles et en langage SQL.-  Maîtrise des outils d'analyse de données tels que Power BI, Tableau, ou équivalent.-  Capacité à travailler en équipe, à communiquer efficacement et à s'adapter à un environnement en évolution rapide.
#
#
#
#
# Bienvenue chez Safran
#
#
#                 Safran est un groupe international de haute technologie opérant dans les domaines de la propulsion et des équipements aéronautiques, de l'espace et de la défense. Implanté sur tous les continents, le Groupe emploie plus de 92 000 collaborateurs pour un ch
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3 de plus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0 / 8
# Alternance - Développeur Orienté Data H/F
# Enedis
#
#
# Courbevoie - 92
#
# Alternance
#
#
#
#
#
#
# Super recruteur
#
#
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Les missions du poste
#
#
#                 Environnement de travail :Enedis assure ses missions de développement et d'exploitation du réseau public de distribution d'électricité dans le cadre de contrats de concession conclus avec les collectivités "Autorités Organisatrices de la Distribution d'Electricité" (AODE).Enedis est ainsi amenée à proposer aux collectivités AODE des services basés sur des données techniques, financières ou encore clientèle (notamment issues des comptages Linky), avec de fortes attentes de leur part en terme de qualité et d'adéquation à leurs besoins. Le Département Concessions du pôle Territoires (équipe de 11 personnes) assure l'expertise nationale du domaine des concessions, porte la maîtrise d'ouvrage des outils SI et coordonne l'organisation de la production opérationnelle des données vers les collectivités AODE.Missions confiées :Au sein de ce Département Concessions, l'apprenti aura pour mission d'appuyer les experts et chefs de projets à améliorer la qualité et la structuration des données destinées aux Collectivités  AODE.En particulier, l'apprenti aura :A contribuer à rationaliser la production des données nécessaires aux Comptes Rendus Annuels d'Activité (CRAC) et aux audits et contrôles réalisés par les collectivités AODE : optimiser et industrialiser l'outil de production des données des CRAC ; mettre en place une solution d'exposition des données (ex. API) pour faciliter la récupération et la vérification de ces données par les différents partenaires.A étudier l'opportunité d'une industrialisation de la chaine de production du référentiel des communes, en tenant compte du COG (Code Officiel Géographique) de l'INSEE et des données des contrats de concessions, en collaboration avec les entités opérationnelles concernées et la Direction des Systèmes d'Information (DSI) ; si opportunité validée, développer les outils requis pour une mise en oeuvre d'un processus automatisé assurant une génération du référentiel à la fois efficiente et sécurisée.A exploiter et valoriser la base de données sur la distribution (montants d'investissements et indicateurs techniques) recueillies au niveau des « conférences départementales NOME », en facilitant l'intégration de ces données sur un site dédié (cloud), en appuyant leur administration sur le site, ou encore en proposant des visualisations graphiques adaptées.
#
#
#
#
#                 Le profil recherché
#
#
#                 Niveau de Diplôme préparé : Bac +5. Ingénieur - Elève en Master 1 ou 2ème année d'Ecole d'ingénieurSpécialisation du diplôme préparé : Système d'information orientée dataDurée du contrat : 2 ansRythme d'alternance :  sur la semaine (3 jours en entreprise et 2 jours à l'école) ou sur 2 semaines (1 semaine entreprise, 1 semaine école)Qualités requises : rigueur, méthode, curiosité, autonomie dans le travail, capacité d'analyse et de propositions, qualité de restitution du travail réalisé, capacité à travailler en équipeCompétences souhaitées :Connaissances en méthodes de développement SI et base de données requises, connaissances en analyse statistique descriptive appréciées, maîtrise des techniques d'analyse de données et des outils associés (Python, R, SQL, etc.). Compétences en conception de schémas de bases de données et l'optimisation des requêtes. Expérience dans l'utilisation ou/et conception d'outil ou d'interface pour l'exposition des données (ex. type API)Confidentialité attendue dans la gestion de données sensibles.Maîtrise des outils bureautiques : Pack Office, Outlook...Pour postuler, n'oubliez pas de joindre à votre candidature votre CV votre lettre de motivation et vos bulletins scolaires des 2 dernières années."Enedis ouvre ses postes à toutes les compétences, toutes les énergies et toutes les personnalités sans exclusion. Conformément aux engagements pris par Enedis en faveur de l'accueil et de l'intégration des personnes en situation de handicap, cet emploi est ouvert à toutes et à tous sous réserve de l'aptitude médicale délivrée par la médecine du travail.Nous attachons une importance particulière à ce que nos futurs collaborateurs agissent au quotidien avec responsabilité éthique et professionnelle, suivant les principes et engagements définis par le Code de Bonne Conduite d'Enedis."
#
#
#
#
#                 Infos complémentaires
#
#
#                 Enedis
#
#
#
#
#
#
#
#
#
#
# Super recruteur
#
#
#
#         Ce recruteur s’engage avec HelloWork sur la transparence et communique :
#
#
# Un salaire sur la majorité de ses offres
# Son process de recrutement
# Diverses informations sur son entreprise (CA, parité, avantages...)
# L'évolution de votre candidature
# Sa politique de télétravail
#
#
#
#
#
# Bienvenue chez Enedis
#
#
#                 Acteur majeur du secteur de l'énergie en France, Enedis distribue l'électricité via le plus grand réseau électrique d'Europe. Présents sur 700 sites sur l'ensemble du territoire, nos 40 000 salariés bénéficient d'un terrain de jeu exceptionnel pour développer un réseau électrique de plus en plus intelligent, connecté et performant. Du raccordement au dépannage des clients en passant par la gestion des données, nos équipes s'engagent chaque jour à relever des défis techniques, technologiques et écologiques.Indépendante, Enedis délivre la même qualité de service aux fournisseurs d'énergie. Comme le prévoit la loi, elle a établi un code de bonne conduite auquel ses collaborateurs sont formés afin d'en respecter les principes et engagements au quotidien.Rejoindre Enedis, c'est intégrer une entreprise à mission, soucieuse de ses impacts environnementaux et sociétaux, soumise au principe de neutralité religieuse et politique et participer à une aventure humaine et collective unique.Alors, prêt à intégrer la Team France électrique ?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4 de plus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0 / 9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Alternant Compliance et Data Protection H/F
# Talentpeople
#
#
# Boulogne-Billancourt - 92
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Les missions du poste
#
#
#                 Vous êtes étudiant(e) en Master spécialisé dans le domaine de la compliance, de la gestion des risques ou de la protection des données personnelles. Vous recherchez une alternance de 12 mois à partir de septembre 2024 au sein d'une entreprise dynamique et innovante.Rejoignez-nous en tant qu'alternant(e) Compliance et data protection et participez à la mise en oeuvre et au suivi des dispositifs de conformité et de protection des données au sein de notre groupe.Vos missions seront les suivantes :* Assurer une veille réglementaire et normative sur les sujets de compliance et de protection des données (RGPD, Sapin II, devoir de vigilance, etc.).* Réaliser des analyses de risques et des contrôles internes sur les processus et les activités liés à la compliance et à la protection des données.* Participer à la rédaction et à la mise à jour des politiques, des procédures et des chartes de compliance et de protection des données.* Sensibiliser et former les collaborateurs aux enjeux et aux bonnes pratiques de compliance et de protection des données.* Accompagner les opérationnels dans la mise en conformité de leurs projets et de leurs traitements de données.* Collaborer avec les différents acteurs internes et externes impliqués dans la compliance et la protection des données (direction juridique, direction des systèmes d'information, délégué à la protection des données, autorités de contrôle, etc.).
#
#
#
#
#                 Le profil recherché
#
#
#                 * Vous êtes titulaire ou en cours d'obtention d'un Master spécialisé dans le domaine de la compliance, de la gestion des risques ou de la protection des données personnelles.* Vous avez une bonne connaissance des réglementations et des normes applicables en matière de compliance et de protection des données.* Vous avez des compétences en analyse de risques, en contrôle interne et en audit.* Vous avez un bon niveau d'anglais, à l'écrit comme à l'oral.* Vous êtes rigoureux(se), organisé(e), autonome et proactif(ve).* Vous avez un bon relationnel, un sens du travail en équipe et une capacité d'adaptation.Nous vous offrons :* Une expérience enrichissante et formatrice au sein d'un groupe multinational et multiculturel très dynamique, présent sur l'ensemble du continent Africain.* Une opportunité de développer vos compétences et votre réseau professionnel.* Une rémunération attractive et des avantages sociaux.* Un accompagnement personnalisé et un suivi régulier de votre parcours.Si vous êtes intéressé(e) par cette offre, merci de nous transmettre votre CV et votre lettre de motivation.
#
#
#
#
# L'entreprise
#
#
#                 CFAO est un acteur majeur dans les domaines de la mobilité, de la santé, des biens de consommation, des infrastructures et de l'énergie.Avec 86 unités opérationnelles, son réseau de distribution est le plus large du continent africain.Partenaire privilégié de grandes marques mondiales, le Groupe intervient sur toute la chaîne de valeur, en s'appuyant sur plus de 170 ans de connaissance terrain et sur les savoir-faire locaux.
# Consultant Junior Alternant - Data & Analytics H/F
# Deloitte
#
#
# La Défense - 92
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Les missions du poste
#
#
#                 Prêts à dire #ISayYes à votre avenir chez Deloitte ?Vous rejoindrez le service AIM (Analytics & Information Management) et ferez partie d'une équipe fantastique de plus de 60 consultants spécialisés dans les sujets Data & Analytics.L'équipe AIM propose une offre complète qui adresse les principaux enjeux sur la data et se décline sur 5 grands domaines d'activités : Stratégie Data, Data Management, Urbanisation & Architecture, Data Visualisation & Intelligence Artificielle/Data Science.Votre rôle au sein de la #Team AIM ?Vous participerez à des missions variées visant à assister nos clients grands comptes, privés ou organismes publics, la conception d'études et de solutions Data & Analytics.Vous serez amené(e) à intervenir sur des missions variées :-  Diagnostic des architectures en data et data management-  Participation à la définition d'architecture data, big data ou intelligence artificielle-  Mise sous contrôle de la qualité des données (clients, fournisseurs, comptables...)-  Conception fonctionnelle et technique de solutions IA et analytics-  Réalisation de modèles d'analyses prédictives et statistiques, machine learning-  Exploration des données à l'aide d'outils de data vizualisationVous développez un set de compétences, partagées avec notre réseau international, et structurées autour des dimensions suivantes : leadership, métier et spécialité. Vous participez aux programmes de formations proposé pour renforcer progressivement ces compétences et en acquérir de nouvelles. Tout au long de votre expérience, vous grandissez grâce à un management de proximité, de responsabilisation et d'accompagnement personnalisé.Et si c'était vous ?Dans le cadre du développement de nos activités Data & Analytics, nous recrutons des alternants pour renforcer notre équipe, avec un rythme d'alternance pouvant correspondre à :-  3 semaines entreprise /1 semaine école ;-  1 mois/1 mois ;-  3 mois/ 3 mois ;-  6 mois entreprise / 6 mois école ;Vous êtes :-  Etudiant en Master 2 d'une école de commerce, d'ingénieurs ou d'une université, avec une spécialisation en data.-  Autonome, dynamique et doté(e) de bonnes qualités relationnelles-  Vous maîtrisez l'anglais écrit et oral.Vous avez eu l'occasion d'acquérir des connaissances approfondies dans au moins un des domaines suivants :-  Qualité des données, analyse, business intelligence, collecte de données, modélisation de data warehouse et de cubes (OLAP), conception de rapports et dashboards (Tableau, Power BI, Qlikview...)-  Vous maîtrisez les environnements et langages de la Data Science : Python, R, SQL, SAS, SPSS, Hadoop, SparkNous accompagnons les organisations publiques et privées dans leurs projets de transformation, nous nous engageons pour l'éducation, l'innovation durable et nous collaborons avec différentes associations (Fondation Deloitte), oeuvrons pour la diversité et la parité (ALL IN) et accompagnons nos Talents dans leurs projets (D for Future).Si vous vous reconnaissez dans nos valeurs et que vous souhaitez rejoindre une entreprise engagée pour l'éducation, l'innovation durable et la diversité.Postulez dès maintenant et rencontrons-nous !Poste basé à Paris La Défense.
#
#
#
#
# L'entreprise
#
#
#                 Tous nos postes sont ouverts au télétravail.Alternance (12 mois) à partir de septembre 2024.Rejoindre Deloitte, c'est accepter une expérience professionnelle enrichissante, où chaque rencontre et chaque mission vous permettent de vous épanouir. C'est évoluer dans un environnement fondé sur la confiance, la transmission et l'intelligence collective pour façonner l'avenir de nos clients. Nous sommes engagés dans une démarche responsable et durable, et notre entreprise est reconnue comme une Great Place to Work, favorisant le bien-être et l'inclusion de tous nos collaborateurs.
#
#
#
#
#
#
#
# HelloWork a estimé le salaire pour cette offre d'alternance
# Le recruteur n'a pas communiqué le salaire de cette offre mais HelloWork vous propose une estimation (le salaire en alternance varie en fonction de l'âge et du niveau d'études du candidat).
#
#
# Estimation basse
# 477,07 €
#
#
#
# Estimation haute
# 1 766,92 €
#
#
#
#
# Cette information vous semble-t-elle utile ?
#
#
#                     Oui
#
#
#                     Non
#
#
#
# Merci pour votre retour !
#
#
#
#
#
#
# Consultant Apprenti - Data Paris H/F
# Capgemini
#
#
# Paris - 75
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Les missions du poste
#
#
#                 Rejoignez l'aventure Capgemini InventCapgemini Invent est la marque d'innovation digitale, de design et de transformation du groupe Capgemini, qui permet aux dirigeants de façonner l'avenir de leurs entreprises. Etablie dans plus de 36 bureaux et 37 studios de création dans le monde, elle comprend une équipe de plus de 10 000 collaborateurs composés d'experts en stratégie, de data scientists, de concepteurs de produits et d'expériences, d'experts en marques et en technologie qui développent de nouveaux services digitaux, produits, expériences et modèles d'affaire pour une croissance durableLa Data est un pilier stratégique du Groupe, et Invent doit franchir un nouveau pas pour devenir une entreprise data-centric. Le nouveau modèle opérationnel permet de multiplier nos succès Data dans l'industrie au sens large, d'accélérer massivement sur la Data Marketing, et de développer les transformations opérationelles tirées par la data pour les fonctions Corporates, tout en continuant à faire la course en tête sur la Data pour l'Intelligent Industry en collaboration étroite avec ER&D. La communauté Data et Data Science sont animées transversalement à l'échelle du cabinet. Votre rôle, votre avenirEn tant que consultant(e) en alternance, vous serez amené(e) à accompagner les Directions Générales sur des problématiques de stratégie, d'organisation et d'efficacité opérationnelle.Intégré(e) dans une équipe projet et au contact du client, vous serez en charge de :* Collecter et d'analyser des données, via la conduite d'entretiens ou l'animation d'ateliers de co-construction.* Etablir des présentations pour nos clients et contribuer à la formalisation des recommandations stratégiques.* Vous aurez également la possibilité de vous investir dans la vie interne du cabinet (recrutement, formations...).
#
#
#
#
#                 Le profil recherché
#
#
#                 Notre candidat idéal* Vous êtes en 4ème ou 5ème année d'Ecole de Commerce, d'Ingénieurs ou d'Université, vous avez une appétence marquée pour les sujets liés aux transformations et à l'innovation digitale,Vous disposez d'une très bonne culture de la donnée,Vous disposez de compétences analytiques et de synthèse, d'excellentes capacités d'organisation  et d'une bonne capacité de communication écrite et orale. Vous êtes enthousiaste avec un esprit entrepreneur et vous avez un niveau d'anglais courant,* Doté(e) d'une forte curiosité intellectuelle et d'une grande capacité d'adaptation, vous êtes ouvert sur l'écosystème des startup et curieux des approches innovantes.Capgemini promeut une culture inclusive dans un cadre multiculturel et créateur de valeur, quel que soit votre parcours, genre, origine culturelle, sociale... notamment au travers de ses réseaux OUTFront et Women@Capgemini. Entreprise handi accueillante, le Groupe développe une politique active d'emploi et d'insertion des personnes en situation d'handicap. Capgemini s'engage pour un numérique responsable en intégrant l'éco-conception et l'accessibilité dans ses projets, et réduira de 90% ses émissions d'ici 2040. Partenaire de différentes associations, Capgemini accompagne les exclus du numérique vers l'autonomie. https://www.capgemini.com/fr-fr/notre-groupe/responsabilite-sociale-et-environnementale/
#
#
#
#
# Bienvenue chez Capgemini
#
#
#                 Capgemini Invent est la marque d'innovation digitale, de design et de transformation du groupe Capgemini, qui permet aux dirigeants de façonner l'avenir de leurs entreprises. Etablie dans plus de 36 bureaux et 37 studios de création dans le monde, elle comprend une équipe de plus de 12 000 collaborateurs composée d'experts en stratégie, de data scientists, de concepteurs de produits et d'expériences, d'experts en marques et en technologie qui développent de nouveaux services digitaux, produits, expériences et modèles d'affaire pour une croissance durable.Capgemini Invent fait partie du groupe Capgemini, un leader mondial, responsable et multiculturel, regroupant 360 000 personnes dans plus de 50 pays. Partenaire stratégique des entreprises pour la transformation de leurs activités en tirant profit de toute la puissance de la technologie, le Groupe est guidé au quotidien par sa raison d'être : libérer les énergies humaines par la technologie pour un avenir inclusif et durable.Fort de 55 ans d'expérience et d'une grande expertise des différents secteurs d'activité, Capgemini est reconnu par ses clients pour répondre à l'ensemble de leurs besoins, de la stratégie et du design jusqu'au management des opérations, en tirant parti des innovations dans les domaines en perpétuelle évolution du cloud, de la data, de l'Intelligence Artificielle, de la connectivité, des logiciels, de l'ingénierie digitale et des plateformes.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3 de plus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0 / 8
# Alternant - Analyste Développeur IA & Data H/F
# Bouygues Telecom
#
#
# Meudon - 92
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Les missions du poste
#
#
# ...
#
#
#
#
# Bienvenue chez SFR
#
#
#                 Informations généralesEntreprise de nouvelles technologies et d'innovation et 2e opérateur Français, SFR révolutionne les usages grâce à son réseau puissant Fibre, 4G, 5G et ses expertises de pointe dans les technologies de la mobilité, l'IA, le big data ou les objets connectés. 1er opérateur à avoir lancé la 3G la 4G et la 5G en France, SFR fait partie du groupe Altice France, acteur pionnier de la convergence entre les télécoms et les médias.Nous sommes près de 10 000 femmes et hommes, partout en France, animés par un objectif : offrir le meilleur à chacun de nos clients.Vivre l'aventure SFR, c'est la certitude de relever de nouveaux challenges chaque jour, d'avoir la chance de laisser son talent et son potentiel s'exprimer, de favoriser une innovation utile et le travail en équipe, pour accélérer l'innovation, la vie des Français, l'avenir mais aussi sa carrière !Toutes nos offres d'emploi sont ouvertes aux personnes en situation de handicap.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 8 de plus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0 / 13
# Alternance Chef.Fe de Projet Data Supply Chain H/F
# Franprix
#
#
# Vitry-sur-Seine - 94
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Détail du poste
#
#
#                 Qui sommes-nous ?  Avec plus de 1100 magasins en France, le réseau Franprix connaît une forte croissance à Paris, en région parisienne, et se développe maintenant dans les grandes villes de France à travers son ambitieux projet d'expansion. Ancrés au coeur de la vie de quartier, nos magasins proposent des services d'ultra-proximité ainsi qu'une gamme de produits étendue et adaptée aux habitudes de consommation. Notre priorité : satisfaire le client au quotidien !  Ce que nous pouvons accomplir ensemble ?  Nous débordons de projets et de dynamisme et à ce titre nous avons besoin d'un.e « chef de projet data Supply Chain » pour nous accompagner dans la refonte de process et d'outils de codification articles et de gestion des assortiments produits.  Dans ce contexte, voici vos principales responsabilités :  · En collaboration avec le responsable du service, vous remettrez à plat et optimiserez le process de codification des articles depuis une carte heuristique dans le but d'améliorer l'existant, gagner en réactivité et dans le cadre de la migration prévue d'ERP.  · Vous améliorerez et automatiserez l'outil de suivi des mouvements d'assortiment, entrée, switch, suppression.  · En collaboration avec la DSI, vous reverrez l'algorithme de codification automatique  En fonction de vos capacités et de votre force de proposition, vos missions pourront êtreamenées à évoluer sur d'autres sujets de simplification et d'optimisation des tâches à non valeur ajoutée.  Vous cherchez un poste à la croisée de la data, du process mining et de la Supply Chain ? Ce poste est fait pour vous !  Cette alternance est à pourvoir en Septembre 2024 pour une durée de 12 mois.
#
#
#
#
#                 Le profil recherché
#
#
#                 Vous êtes étudiant.e en 2ème ou 3ème année de Grande Ecole de Commerce ou d'Ingénieur.  Expérience  Vous avez idéalement une première expérience significative en gestion de projet ou conseil, ou dans le secteur de la Grande distribution ou dans l'industrie ; sur un métier en lien direct ou indirect avec la Supply Chain, l'amélioration continue.  Compétences  Vous avez les bons réflexes d'automatisation, de lean. Vous êtes capables de rapidement identifier ou et comment simplifier et améliorer les processus, en lien notamment avec de la gestion de données.  Vous avez conscience des outils et moyens d'automatisation les chosesVous avez des connaissances en gestion ou digitalisation de données et vous maitrisez Pack Office, Excel, VBA ; la maîtrise de Python est un plus, tout comme la connaissance d'outil de BI comme Tableau, ou d'outils de nocode comme Make (integromat)...Connaissance du fonctionnement d'une chaîne d'approvisionnement, maîtrise des grands enjeux de la Supply Chain d'une entreprise de distribution.Personnalité· Intérêt pour les projets· Rigueur et méthodes· Esprit d'analyse et de synthèse· Autonomie, esprit d'initiative· Bon sens relationnelC'est quoi la suite ?1. Un premier appel avec l'équipe RH.2. Un échange plus approfondi votre parcours et vos motivations.3. Un entretien avec votre futur manager pendant un entretien approfondi sur les missions.Si ce challenge est le vôtre, nous avons hâte de vous rencontrer !
#
#
#
#
#
#
#
#
# Alternance Développeur Data - Energie - Île-De-France H/F
# Sopra Steria
#
#
# Courbevoie - 92
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#             Participez au monde numérique de demain!
#
#
#
#                 Les missions du poste
#
#
#                 Votre futur environnement de travail :Nos équipes travaillent à la mise en place un espace de services à destination des clients collectivités locales d'un acteur majeur de l'électricité en France.Le projet consiste mettre en place une plateforme de visualisation et d'analyse des données de consommation et de production d'électricité. Il s'inscrit dans la transition écologique de nos territoires en les accompagnant dans la sobriété énergétique.Dans ce cadre, vous intervenez sur cette plateforme afin d'enrichir les fonctionnalités existantes et/ou de proposer de nouvelles fonctionnalités.Votre rôle et vos missions :-  Vous participez aux cérémonies agiles : Daily meeting, grooming, démonstration, rétrospective. -  Vous prenez en charge les User Stories dès la phase de conception-  Vous réalisez les travaux de support d'analyses de données-  Vous développez les corrections et procédure de rattrapageEnvironnement technologique/fonctionnel : Python, Big Data, SafeLes apports de l'alternance :-  Monter en compétences sur le secteur de l'énergie et ses enjeux-  Découvrir une application riche et évolutive-  Appliquer la méthodologie SAFE
#
#
#
#
#                 Le profil recherché
#
#
#                 Votre profil :Vous aimez travailler en équipe, vous êtes bon(ne) communicant(e) et curieux(se) techniquement, vous aimez prendre des initiatives et résoudre des challenges techniques.Etudiant(e) en dernière année d'école d'Ingénieurs ou universitaire ou formation équivalente, vous êtes à la recherche d'une alternance. Vous êtes familier(e) des technologies telles que Python.
#
#
#
#
#                 Infos complémentaires
#
#
#                 -  Un accord télétravail pour télétravailler jusqu'à 2 jours par semaine selon vos missions.-  Un package avantages intéressants : une mutuelle, un CSE, des titres restaurants, un accord d'intéressement, et des primes vacances.-  Plusieurs centaines de formations accessibles en toute autonomie depuis l'app mobile avec Sopra Steria Academy-  La possibilité de s'engager auprès de notre fondation ou de notre partenaire « Vendredi ».-  De très nombreuses opportunités en CDI peuvent vous attendre à l'issue de l'alternance.Employeur inclusif et engagé, notre société oeuvre chaque jour pour lutter contre toute forme de discrimination et favoriser un environnement de travail respectueux. C'est pourquoi, attachés à la mixité et à la diversité, nous encourageons toutes les candidatures et tous les profils.https://www.soprasteria.fr/nous-connaitre/nos-engagements
#
#
#
#
# Bienvenue chez Sopra Steria
#
#
#                 Sopra Steria, acteur majeur de la Tech en Europe avec 56 000 collaborateurs dans près de 30 pays, est reconnu pour ses activités de conseil, de services numériques et d'édition de logiciels. Il aide ses clients à mener leur transformation digitale et à obtenir des bénéfices concrets et durables. Le Groupe apporte une réponse globale aux enjeux de compétitivité des grandes entreprises et organisations, combinant une connaissance approfondie des secteurs d'activité et des technologies innovantes à une approche résolument collaborative.  Sopra Steria place l'humain au centre de son action et s'engage auprès de ses clients à tirer le meilleur parti du digital pour construire un avenir positif. En 2023, le Groupe a réalisé un chiffre d'affaires de 5, 8 milliards d'Euros.  The world is how we shape IT
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 27 de plus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0 / 32
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Alternant Data & Analytics Audit Septembre 2024 H/F
# KPMG
#
#
# Courbevoie - 92
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Les missions du poste
#
#
#                 Vos challengesEn collaboration avec l'équipe et sous la supervision d'un manager, vous avez envie de :* Mettre en oeuvre des techniques d'analyse de données pour le commissariat aux comptes ;* Développer vos compétences sur les outils Data visualisation (Power BI) et de traitement de données (Alteryx) ;* Participer au développement de nouvelles solutions Data&Analytics permettant une analyse plus pertinente des risques sur les transactions financières de nos clients ;* Développer votre capacité d'analyse des données financières et votre esprit critique.
#
#
#
#
#                 Le profil recherché
#
#
#                 Vous êtes en deuxième ou troisième année de BUT Gestion des entreprises et des administrations ou BUT Sciences de données et vous avez une forte motivation pour l'utilisation des outils numériques.Pas de prérequis attendus, cependant vous disposez d'une forte appétence pour la Data et la comptabilité.Vous êtes également reconnu pour les qualités/compétences suivantes :* Rigueur et capacité à s'investir dans les sujets complexes ;* Qualités d'analyses et de synthèses ;* Qualités de communication écrites et orales ;* Esprit d'équipe et d'initiative (proactivité) ;* Bonne maîtrise de l'anglais.Vous vous reconnaissez dans cette description ?... n'hésitez plus, postulez et rencontrons-nous !Localisation :Vous serez basé à La Défense dans le cadre d'un contrat Alternance à partir de septembre 2024.N'attendez plus, rejoignez l'équipe Digital Audit Innovation et un environnement de travail de qualité où le sens du collectif est clé.Tous nos postes sont ouverts aux personnes en situation de handicap.
#
#
#
#
# Bienvenue chez KPMG
#
#
#                 En quête de nouveaux challenges, vous souhaitez rejoindre une société à mission en plein essor ?Comme nos 10 000 collaborateurs, faites le choix d'une société à mission en plein essor, où la contribution de chacun et chacune est encouragée pour grandir ensemble. Faites le choix d'exceller autrement en oeuvrant pour une performance durable autant que financière. Faites le choix, chaque jour, d'impacter positivement l'économie, les territoires et la société depuis un de nos 200 bureaux en France. Faites le choix de KPMG.Pour accompagner notre croissance, nous recrutons un Alternant Data & Analytics Audit F/H septembre 2024
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 9 de plus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0 / 14
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# HelloWork a estimé le salaire pour cette offre d'alternance
# Le recruteur n'a pas communiqué le salaire de cette offre mais HelloWork vous propose une estimation (le salaire en alternance varie en fonction de l'âge et du niveau d'études du candidat).
#
#
# Estimation basse
# 477,07 €
#
#
#
# Estimation haute
# 1 766,92 €
#
#
#
#
# Cette information vous semble-t-elle utile ?
#
#
#                     Oui
#
#
#                     Non
#
#
#
# Merci pour votre retour !
# Data Engineer H/F
# Seqens
#
#
# Issy-les-Moulineaux - 92
#
# Alternance
#
#
#
#
# La rémunération en alternance varie en fonction de l'âge et du niveau d'études du candidat.
#
#
#
#
#                 Les missions du poste
#
#
#                 Vous prenez en charge les activités suivantes :-  Vous gérez l'alimentation de l'entrepôt de données (modélisation, développement, test, accompagnement des recettes...)-  Vous assurez la mise en place d'interfaces inter-applicatives (architecture en data hub avec des demi-flux)-  Vous participez au projet de modernisation de l'architecture data (migration de données & flux, recette technique, documentation
#
#
#
#
#                 Le profil recherché
#
#
#                 Formation/ expérience : Vous recherchez une alternance pour une durée de 24 mois, à partir de septembre 2024 dans le cadre d'une formation informatique de niveau Bac +4/5, de type Ecole d'Ingénieur, Ecole spécialisée ou Université.Compétences/qualités requises :Vous présentez un excellent relationnel, réel esprit d'équipe et réactivité. Maîtrise des bases du langage SQL et connaissance d'un ETL (idéalement Talend).
#
#
#
#
#                 Infos complémentaires
#
#
#                 Avantages : Horaires variables, 6 semaines de congés payés, CSE, Prime vacances de 830€ bruts, 13e mois, Intéressement, Prime académique, Titres restaurants 11, 97€ par jour, 60% de prise en charge Navigo.Pourquoi postuler ?-  Intégrer Seqens c'est rejoindre une entreprise à l'environnement dynamique, propice à l'apprentissage et à l'épanouissement professionnel.-  Être alternant chez Seqens, c'est bénéficier d'un encadrement de qualité et de formations adaptées, facilitant le développement de vos compétences et de bénéficier de perspectives professionnelles attrayantes.
#
#
#
#
# Bienvenue chez Seqens
#
#
#                 Présentation de la société :Seqens société à mission, est l'un des acteurs majeurs du logement social en Ile-de-France. Fort d'un patrimoine de 106 000 logements et d'une perspective de construction de plus de 4000 logements par an, il est le 1er constructeur de logement social sur le territoire francilien.Filiale d'Action Logement, Seqens réunit aujourd'hui 1 600 collaborateurs, qui conjuguent leurs savoir-faire sur les métiers de l'habitat social.Pour mener à bien nos projets nous recherchons de nouveaux talents désireux d'évoluer au sein d'un environnement innovant !Grâce à notre engagement fort et notre développement d'une politique d'alternance volontariste, nous avons obtenu la labellisation « HappyTrainees » pour les alternants et les stagiaires avec un taux de satisfaction général de 4, 11/5 et un taux de recommandation de 95, 7%
#
#
#
#
#
#
#
# HelloWork a estimé le salaire pour cette offre d'alternance
# Le recruteur n'a pas communiqué le salaire de cette offre mais HelloWork vous propose une estimation (le salaire en alternance varie en fonction de l'âge et du niveau d'études du candidat).
#
#
# Estimation basse
# 477,07 €
#
#
#
# Estimation haute
# 1 766,92 €
#
#
#
#
# Cette information vous semble-t-elle utile ?
#
#
#                     Oui
#
#
#                     Non
#
#
#
# Merci pour votre retour !

# %%
for link in links:
    driver.get(link)
    content = driver.page_source 
    soup = BeautifulSoup(content, 'html.parser')
    job_description= soup.find('div', class_='tw-col-span-full lg:tw-col-span-8')
    job = job_description.get_text()
    email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
    emails = re.findall(email_pattern, job)
    
    if emails:
        for email in emails:
            print("Email found:", email)
